# %% [markdown]
# <a href="https://colab.research.google.com/github/madanjha/PythonDS/blob/main/Census_income_29_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://drive.google.com/file/d/1_CPUR_ANFIe2IFrYeQoLXAGNnQtG4mHE/view?usp=sharing
# Out:
#   File "<ipython-input-69-fb5da6af7b53>", line 1
#     https://drive.google.com/file/d/1_CPUR_ANFIe2IFrYeQoLXAGNnQtG4mHE/view?usp=sharing
#                                      ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/content/census_income (1).csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
#duplicates
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
#outliers
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for col in df.columns:
  if df[col].dtype!='object':
    sns.boxplot(data=df,y=col)
    plt.show()

# %%
df['capital-loss'].value_counts()
# Out:
# capital-loss
# 0       31018
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: count, Length: 92, dtype: int64

# %%
for col in df.columns:
  if df[col].dtype=='object':
    print(f"{col}: {df[col].unique()}")
    print()
# Out:
# workclass: ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# education: ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
#
# marital-status: ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
#
# occupation: ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
#
# relationship: ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
#
# race: ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
#
# sex: ['Male' 'Female']
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
df[df['education-num']<5]['education'].unique()
# Out:
# array(['7th-8th', '5th-6th', '1st-4th', 'Preschool'], dtype=object)

# %%
df[df['education-num']<5]
# Out:
#        age  workclass  fnlwgt  education  education-num  \
# 15      34    Private  245487    7th-8th              4
# 56      46    Private  216666    5th-6th              3
# 61      32          ?  293936    7th-8th              4
# 79      31  Local-gov  125927    7th-8th              4
# 160     68          ?   38317    1st-4th              2
# ...    ...        ...     ...        ...            ...
# 32431   51    Private  274502    7th-8th              4
# 32432   36    Private  208068  Preschool              1
# 32448   61    Private  137554    7th-8th              4
# 32479   64  State-gov  222966    7th-8th              4
# 32517   36    Private  131459    7th-8th              4
#
#               marital-status         occupation   relationship  \
# 15        Married-civ-spouse   Transport-moving        Husband
# 56        Married-civ-spouse  Machine-op-inspct        Husband
# 61     Married-spouse-absent                  ?  Not-in-family
# ...

# %%
df[df['workclass']=='?']['education'].value_counts()
# Out:
# education
# HS-grad         532
# Some-college    514
# Bachelors       173
# 11th            118
# 10th            100
# 7th-8th          72
# Assoc-voc        61
# 9th              51
# Masters          48
# Assoc-acdm       47
# 12th             40
# 5th-6th          30
# Prof-school      18
# Doctorate        15
# 1st-4th          12
# Preschool         5
# Name: count, dtype: int64

# %%
df['workclass'].mode()
# Out:
# 0    Private
# Name: workclass, dtype: object

# %%
df['occupation'].mode()
# Out:
# 0    Prof-specialty
# Name: occupation, dtype: object

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
#? - replace with null value

#1- drop the null values from the dataset
#2- fill with suitable value(doesnt work in this casestudy)
#3- use imputer

# %%
x=['workclass','occupation','native-country']

# %%
import numpy as np

# %%
for col in x:
  df[col].replace('?',np.NaN,inplace=True)
# Out:
# <ipython-input-92-ad9413dbe2b0>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace('?',np.NaN,inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     582
# annual_income        0
# dtype: int64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
null-9(A),3(B)

9-null
3-null
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <ipython-input-95-0a2eacbdba67>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   null-9(A),3(B)
# <ipython-input-95-0a2eacbdba67>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   null-9(A),3(B)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-0a2eacbdba67> in <cell line: 1>()
# ----> 1 null-9(A),3(B)
#       2
#       3 9-null
#       4 3-null
#
# NameError: name 'null' is not defined

# %%
#row-61(all 3 column)

#A-56
#c-45
#g-1333

# %%
df[(df['occupation'].isnull())&(df['native-country'].isnull())]
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 61      32       NaN  293936       7th-8th              4
# 297     39       NaN  157443       Masters             14
# 1152    24       NaN   35633  Some-college             10
# 1676    64       NaN  168340       HS-grad              9
# 2513    47       NaN  174525       HS-grad              9
# 3131    25       NaN  237865  Some-college             10
# 3579    21       NaN  180303     Bachelors             13
# 3834    32       NaN  169886     Bachelors             13
# 6059    35       NaN  163582          10th              6
# 7862    29       NaN  125159  Some-college             10
# 9616    32       NaN  647882       HS-grad              9
# 11614   35       NaN  103710     Bachelors             13
# 12996   37       NaN  122265       HS-grad              9
# 16488   33       NaN  119918     Bachelors             13
# 16838   28       NaN  149646  Some-college             10
# ...

# %% [markdown]
# label encoding:
# note down the labels(row number for null value in each column)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
for col in df.columns:
  if df[col].dtype=='object':
    df[col]=l.fit_transform(df[col])
    print(l.classes_)
# Out:
# ['Federal-gov' 'Local-gov' 'Never-worked' 'Private' 'Self-emp-inc'
#  'Self-emp-not-inc' 'State-gov' 'Without-pay' nan]
# ['10th' '11th' '12th' '1st-4th' '5th-6th' '7th-8th' '9th' 'Assoc-acdm'
#  'Assoc-voc' 'Bachelors' 'Doctorate' 'HS-grad' 'Masters' 'Preschool'
#  'Prof-school' 'Some-college']
# ['Divorced' 'Married-AF-spouse' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Never-married' 'Separated' 'Widowed']
# ['Adm-clerical' 'Armed-Forces' 'Craft-repair' 'Exec-managerial'
#  'Farming-fishing' 'Handlers-cleaners' 'Machine-op-inspct' 'Other-service'
#  'Priv-house-serv' 'Prof-specialty' 'Protective-serv' 'Sales'
#  'Tech-support' 'Transport-moving' nan]
# ['Husband' 'Not-in-family' 'Other-relative' 'Own-child' 'Unmarried' 'Wife']
# ['Amer-Indian-Eskimo' 'Asian-Pac-Islander' 'Black' 'Other' 'White']
# ['Female' 'Male']
# ['Cambodia' 'Canada' 'China' 'Columbia' 'Cuba' 'Dominican-Republic'
#  'Ecuador' 'El-Salvador' 'England' 'France' 'Germany' 'Greece' 'Guatemala'
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          6   77516          9             13               4
# 1   50          5   83311          9             13               2
# 2   38          3  215646         11              9               0
# 3   53          3  234721          1              7               2
# 4   28          3  338409          9             13               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           0             1     4    1          2174             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours-per-week  native-country  annual_income
# 0              40              38              0
# 1              13              38              0
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df.iloc[61]#row -61 where we have null value

     x            y
18  apple   0    dog   0
61  null    2    zebra 2
86  cat     1    null  1
76  null    2    null  1

replace 2- null(x)
replace 1 -null(y)
# Out:
# age                   32
# workclass              8
# fnlwgt            293936
# education              5
# education-num          4
# marital-status         3
# occupation            14
# relationship           1
# race                   4
# sex                    1
# capital-gain           0
# capital-loss           0
# hours-per-week        40
# native-country        41
# annual_income          0
# Name: 61, dtype: int64

# %%
#workclass(null)-8
#occupation(null)-14
#native-country(null)-41

# %%
?-null value(impute)
label encoding (all null-numerical)
numerical(null)-null value
null -value-> imputer

# %%
df['workclass'].replace(8,np.NAN,inplace=True)
df['occupation'].replace(14,np.NAN,inplace=True)
df['native-country'].replace(41,np.NAN,inplace=True)
# Out:
# <ipython-input-103-8ef74d68a770>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['workclass'].replace(8,np.NAN,inplace=True)
# <ipython-input-103-8ef74d68a770>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     582
# annual_income        0
# dtype: int64

# %%
df.head(5)
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39        6.0   77516          9             13               4
# 1   50        5.0   83311          9             13               2
# 2   38        3.0  215646         11              9               0
# 3   53        3.0  234721          1              7               2
# 4   28        3.0  338409          9             13               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0         0.0             1     4    1          2174             0
# 1         3.0             0     4    1             0             0
# 2         5.0             1     4    1             0             0
# 3         5.0             0     2    1             0             0
# 4         9.0             5     2    0             0             0
#
#    hours-per-week  native-country  annual_income
# 0              40            38.0              0
# 1              13            38.0              0
# ...

# %%
#imputers:#replace the null value with the closest values
#knn imputer(k nearest neighbours)

# %%
col=df.columns
col
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer

# %%
impute=KNNImputer(n_neighbors=7)

# %%
df=impute.fit_transform(df)

# %%
df=pd.DataFrame(df,columns=col)

# %%
df
# Out:
#         age  workclass    fnlwgt  education  education-num  marital-status  \
# 0      39.0        6.0   77516.0        9.0           13.0             4.0
# 1      50.0        5.0   83311.0        9.0           13.0             2.0
# 2      38.0        3.0  215646.0       11.0            9.0             0.0
# 3      53.0        3.0  234721.0        1.0            7.0             2.0
# 4      28.0        3.0  338409.0        9.0           13.0             2.0
# ...     ...        ...       ...        ...            ...             ...
# 32532  27.0        3.0  257302.0        7.0           12.0             2.0
# 32533  40.0        3.0  154374.0       11.0            9.0             2.0
# 32534  58.0        3.0  151910.0       11.0            9.0             6.0
# 32535  22.0        3.0  201490.0       11.0            9.0             4.0
# 32536  52.0        4.0  287927.0       11.0            9.0             2.0
#
# ...

# %%
#
x=df.drop('annual_income',axis=1)
y=df['annual_income']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=10000)

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import *

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.89      4905
#          1.0       0.73      0.39      0.51      1603
#
#     accuracy                           0.81      6508
#    macro avg       0.78      0.67      0.70      6508
# weighted avg       0.80      0.81      0.79      6508

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87      4905
#          1.0       0.61      0.64      0.62      1603
#
#     accuracy                           0.81      6508
#    macro avg       0.75      0.75      0.75      6508
# weighted avg       0.81      0.81      0.81      6508

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,12),dpi=200)
plot_tree(model,feature_names=x.columns,filled=True)
plt.show()

# %%
#random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=300)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
y_pred=model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91      4905
#          1.0       0.76      0.64      0.69      1603
#
#     accuracy                           0.86      6508
#    macro avg       0.82      0.79      0.80      6508
# weighted avg       0.86      0.86      0.86      6508

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=9)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred=model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.95      0.87      4905
#          1.0       0.65      0.28      0.40      1603
#
#     accuracy                           0.79      6508
#    macro avg       0.73      0.62      0.63      6508
# weighted avg       0.77      0.79      0.75      6508

# %%
f1_score=(2)/((1/precision)+(1/recall))

# %%
a=pd.DataFrame([[42,2,16788,13,14,1,10,1,4,1,10000,0,40,24]],columns=x.columns)
a
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   42          2   16788         13             14               1
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0          10             1     4    1         10000             0
#
#    hours-per-week  native-country
# 0              40              24

# %%
X_train.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')

# %%
a_pred=model.predict(a)
a_pred
#salary->(>50K)
# Out:
# array([1.])

# %%
x        x_a  x_b x_c

a    1    1    0   0
b    2    0    1   0
a    3    1    0   0
c    4    0    0   1
a    5    1    0   0

# %%
#label
x
0
1
0
2
0
