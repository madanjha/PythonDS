# %% [markdown]
# <a href="https://colab.research.google.com/github/madanjha/PythonDS/blob/main/LogisticRegression_1_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
drive link: https://drive.google.com/file/d/1jbf347zyrfZsaqQnkfdDk3VIhKiGaeUP/view?usp=sharing

# %%
I will start the session at 10:7AM, waiting for others to join

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/content/bank-additional-full_final (1).csv',sep=';')

# %%
df
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
df[df['y'].isnull()]
# Out:
#        age  job marital education default housing loan contact month  \
# 41188  NaN  NaN     NaN       NaN     NaN     NaN  NaN     NaN   NaN
# 41191  NaN  NaN     NaN       NaN     NaN     NaN  NaN     NaN   NaN
# 41197  NaN  NaN     NaN       NaN     NaN     NaN  NaN     NaN   NaN
#
#       day_of_week  ...  campaign  pdays  previous  poutcome emp.var.rate  \
# 41188         NaN  ...       NaN    NaN       NaN       NaN          NaN
# 41191         NaN  ...       NaN    NaN       NaN       NaN          NaN
# 41197         NaN  ...       NaN    NaN       NaN       NaN          NaN
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 41188             NaN            NaN        NaN          NaN  NaN
# 41191             NaN            NaN        NaN          NaN  NaN
# 41197             NaN            NaN        NaN          NaN  NaN
#
# [3 rows x 21 columns]

# %%
#drop
df.dropna(inplace=True)

# %%
df
# Out:
#         age         job  marital            education  default housing loan  \
# 0      56.0   housemaid  married             basic.4y       no      no   no
# 1      57.0    services  married          high.school  unknown      no   no
# 2      37.0    services  married          high.school       no     yes   no
# 3      40.0      admin.  married             basic.6y       no      no   no
# 4      56.0    services  married          high.school       no      no  yes
# ...     ...         ...      ...                  ...      ...     ...  ...
# 41185  56.0     retired  married    university.degree       no     yes   no
# 41186  44.0  technician  married  professional.course       no      no   no
# 41187  74.0     retired  married  professional.course       no     yes   no
# 41193  94.0     retired  married  professional.course       no     yes   no
# 41194  74.0     retired  married  professional.course       no     yes   no
#
# ...

# %%
#duplicates

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         age          job  marital            education  default housing loan  \
# 0      56.0    housemaid  married             basic.4y       no      no   no
# 1      57.0     services  married          high.school  unknown      no   no
# 2      37.0     services  married          high.school       no     yes   no
# 3      40.0       admin.  married             basic.6y       no      no   no
# 4      56.0     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 41184  46.0  blue-collar  married  professional.course       no      no   no
# 41185  56.0      retired  married    university.degree       no     yes   no
# 41186  44.0   technician  married  professional.course       no      no   no
# 41187  74.0      retired  married  professional.course       no     yes   no
# 41193  94.0      retired  married  professional.course       no     yes   no
#
# ...

# %%
for col in df.columns:
  if df[col].dtype=='object':
    print(f'{col}: {df[col].unique()}')
    print()
# Out:
# job: ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
#
# marital: ['married' 'single' 'divorced' 'unknown']
#
# education: ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
#
# default: ['no' 'unknown' 'yes']
#
# housing: ['no' 'yes' 'unknown']
#
# loan: ['no' 'yes' 'unknown']
#
# contact: ['telephone' 'cellular']
#
# month: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
#
# day_of_week: ['mon' 'tue' 'wed' 'thu' 'fri']
#
# poutcome: ['nonexistent' 'failure' 'success']
#
# y: ['no' 'yes']

# %%
df[df['job']=='unknown']
# Out:
#         age      job   marital            education  default  housing  \
# 29     55.0  unknown   married    university.degree  unknown  unknown
# 35     55.0  unknown   married             basic.4y  unknown      yes
# 73     57.0  unknown   married              unknown  unknown       no
# 91     57.0  unknown   married              unknown  unknown      yes
# 144    38.0  unknown  divorced          high.school  unknown      yes
# ...     ...      ...       ...                  ...      ...      ...
# 40370  59.0  unknown   married              unknown       no       no
# 40428  64.0  unknown   married              unknown       no      yes
# 40656  67.0  unknown  divorced              unknown  unknown      yes
# 41005  63.0  unknown   married  professional.course       no       no
# 41108  64.0  unknown   married              unknown       no       no
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
for col in df.columns:
  if df[col].dtype=='object':
    print(f'{col}: {len(df[df[col]=="unknown"])}')
# Out:
# job: 330
# marital: 80
# education: 1730
# default: 0
# housing: 990
# loan: 990
# contact: 0
# month: 0
# day_of_week: 0
# poutcome: 0
# y: 0

# %%
df['default'].value_counts()
# Out:
# default
# no         32578
# unknown     8596
# yes            3
# Name: count, dtype: int64

# %%
df['default']=df['default'].replace('unknown','no')

# %%
df['default'].value_counts()
# Out:
# default
# no     41174
# yes        3
# Name: count, dtype: int64

# %%
df[(df['job']=='unknown')&(df['marital']=='unknown')&(df['education']=='unknown')]
# Out:
#         age      job  marital education default housing loan   contact month  \
# 14788  45.0  unknown  unknown   unknown      no     yes  yes  cellular   jul
# 14789  45.0  unknown  unknown   unknown      no     yes   no  cellular   jul
# 17344  49.0  unknown  unknown   unknown      no     yes  yes  cellular   jul
# 17421  55.0  unknown  unknown   unknown      no     yes   no  cellular   jul
# 17652  41.0  unknown  unknown   unknown      no     yes   no  cellular   jul
#
#       day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 14788         wed  ...       1.0  999.0       0.0  nonexistent          1.4
# 14789         wed  ...       1.0  999.0       0.0  nonexistent          1.4
# 17344         mon  ...       9.0  999.0       0.0  nonexistent          1.4
# 17421         mon  ...       1.0  999.0       0.0  nonexistent          1.4
# 17652         mon  ...      13.0  999.0       0.0  nonexistent          1.4
#
# ...

# %%
#logistic regression-classification
#mathematical -sigmoid function
S=1/(1+exp(-y))
S=(0,1)
S=0.2
  0.5
  0.77
  0.97

0.5<-classify=0
0.5>-classify=1

S=1/(1+exp(-y))

y= linear regression

1 independent 1 dependent

S=1/(1+exp(-(mx+c)))

>1 independent 1 dependent

S=1/(1+exp(-(a1x1+a2x2+..+d)))

# %%
#homoscedasticity
#hetroscedasticity
